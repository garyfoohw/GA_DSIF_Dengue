# %%
import glob, os
import json
import pandas as pd
from area import area

# %%
root=os.getcwd()

# %%
directories=[
            "dengue-cases-central",
            "dengue-cases-north-east",
            "dengue-cases-south-east",
            "dengue-cases-south-west",
            ]

# %%
df_comb=pd.DataFrame()

# %%
#if you encounter error, restart kernel.
for directory in directories:
    os.chdir(root+f'/../assets/datagov/{directory}/')
    current_list=[]
    for file in glob.glob("*.geojson"):
        js=json.load(open(file))
        features=js['features']
#         current_list.extend(features)
        df=pd.DataFrame(features)
        df['file']=directory
        df['desc']=df['properties'].apply(lambda x: x['Description'])
        df['coords']=df['geometry'].apply(lambda x: x['coordinates'][0])
        df.drop(columns=["properties","type"],inplace=True)
#         display(df)
        df_comb=pd.concat([df_comb,df],axis=0,ignore_index=True)

# %%
df_comb
# Out:
#                                              geometry  \
# 0   {'type': 'Polygon', 'coordinates': [[[103.8465...
# 1   {'type': 'Polygon', 'coordinates': [[[103.8519...
# 2   {'type': 'Polygon', 'coordinates': [[[103.8842...
# 3   {'type': 'Polygon', 'coordinates': [[[103.8411...
# 4   {'type': 'Polygon', 'coordinates': [[[103.8465...
# ..                                                ...
# 71  {'type': 'Polygon', 'coordinates': [[[103.7423...
# 72  {'type': 'Polygon', 'coordinates': [[[103.8070...
# 73  {'type': 'Polygon', 'coordinates': [[[103.7459...
# 74  {'type': 'Polygon', 'coordinates': [[[103.7674...
# 75  {'type': 'Polygon', 'coordinates': [[[103.7477...
#
#                        file  \
# 0      dengue-cases-central
# 1      dengue-cases-central
# 2      dengue-cases-central
# 3      dengue-cases-central
# 4      dengue-cases-central
# ..                      ...
# 71  dengue-cases-south-west
# 72  dengue-cases-south-west
# 73  dengue-cases-south-west
# 74  dengue-cases-south-west
# 75  dengue-cases-south-west
#
#                                                  desc  \
# 0   <center><table><tr><th colspan='2' align='cent...
# 1   <center><table><tr><th colspan='2' align='cent...
# 2   <center><table><tr><th colspan='2' align='cent...
# 3   <center><table><tr><th colspan='2' align='cent...
# 4   <center><table><tr><th colspan='2' align='cent...
# ..                                                ...
# 71  <center><table><tr><th colspan='2' align='cent...
# 72  <center><table><tr><th colspan='2' align='cent...
# 73  <center><table><tr><th colspan='2' align='cent...
# 74  <center><table><tr><th colspan='2' align='cent...
# 75  <center><table><tr><th colspan='2' align='cent...
#
#                                                coords
# 0   [[103.84655938962, 1.33835592864932, 0.0], [10...
# 1   [[103.851950810471, 1.34739953784411, 0.0], [1...
# 2   [[103.884299493455, 1.36910380931713, 0.0], [1...
# 3   [[103.841168094861, 1.35644324088621, 0.0], [1...
# 4   [[103.846559536434, 1.36548686057736, 0.0], [1...
# ..                                                ...
# 71  [[103.742326074382, 1.35282407863695, 0.0], [1...
# 72  [[103.807023444943, 1.27685902625353, 0.0], [1...
# 73  [[103.745920648834, 1.34378057771838, 0.0], [1...
# 74  [[103.767485844328, 1.35282489696018, 0.0], [1...
# 75  [[103.747717198056, 1.36005918306542, 0.0], [1...
#
# [76 rows x 4 columns]

# %%
regex=r'JOIN_COUNT<\/th>\s?<td>(\d+)<\/td>'
df_comb['breeding_habitat_count']=df_comb['desc'].str.extract(pat=regex)

df_comb['area']=df_comb['geometry'].apply(lambda x: area(x))

# %%
df_comb.drop(columns=["desc","geometry"],inplace=True)

# %%
df_comb
# Out:
#                        file  \
# 0      dengue-cases-central
# 1      dengue-cases-central
# 2      dengue-cases-central
# 3      dengue-cases-central
# 4      dengue-cases-central
# ..                      ...
# 71  dengue-cases-south-west
# 72  dengue-cases-south-west
# 73  dengue-cases-south-west
# 74  dengue-cases-south-west
# 75  dengue-cases-south-west
#
#                                                coords breeding_habitat_count  \
# 0   [[103.84655938962, 1.33835592864932, 0.0], [10...                      4
# 1   [[103.851950810471, 1.34739953784411, 0.0], [1...                      2
# 2   [[103.884299493455, 1.36910380931713, 0.0], [1...                      3
# 3   [[103.841168094861, 1.35644324088621, 0.0], [1...                      1
# 4   [[103.846559536434, 1.36548686057736, 0.0], [1...                      1
# ..                                                ...                    ...
# 71  [[103.742326074382, 1.35282407863695, 0.0], [1...                      1
# 72  [[103.807023444943, 1.27685902625353, 0.0], [1...                      1
# 73  [[103.745920648834, 1.34378057771838, 0.0], [1...                      1
# 74  [[103.767485844328, 1.35282489696018, 0.0], [1...                      1
# 75  [[103.747717198056, 1.36005918306542, 0.0], [1...                      1
#
#             area
# 0   40269.282884
# 1   40269.276655
# 2   40269.238463
# 3   40269.276397
# 4   40269.270830
# ..           ...
# 71  40269.178736
# 72  40269.303786
# 73  40269.190581
# 74  40269.226884
# 75  40269.187148
#
# [76 rows x 4 columns]

# %%
df_comb.to_csv(root+f'/../assets/datagov/dengue_cases.csv')
