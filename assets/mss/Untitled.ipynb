# %% [markdown]
# # 1. Import Packages and Read Files

# %%
#Import packages
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer

# this setting widens how many characters pandas will display in a column:
pd.options.display.max_colwidth = 400

# %%
#Read file as stations
stations = pd.read_csv('stations.csv')

# %%
# Convert all columns to lowercase and replace spaces in column names.
stations.columns = stations.columns.str.lower().str.replace(' ', '_')

# %%
# Check for missing values.
stations.isnull().sum()
# Out:
# unnamed:_0      0
# station_code    0
# station_name    0
# longitude       0
# latitude        0
# dtype: int64

# %%
#Check data in stations
stations.head()
# Out:
#    unnamed:_0 station_code            station_name   longitude  latitude
# 0           0          S06              Paya Lebar  103.903733  1.357133
# 1           1          S07    Macritchie Reservoir  103.833900  1.341800
# 2           2          S08  Lower Peirce Reservoir  103.827067  1.370033
# 3           3         S101          Jurong (North)  103.713400  1.350533
# 4           4         S102          Semakau Island  103.765717  1.190167

# %%
#drop unnamed column
stations.drop(['unnamed:_0'], axis=1, inplace=True)

# %%
#Check data again
stations.head()
# Out:
#   station_code            station_name   longitude  latitude
# 0          S06              Paya Lebar  103.903733  1.357133
# 1          S07    Macritchie Reservoir  103.833900  1.341800
# 2          S08  Lower Peirce Reservoir  103.827067  1.370033
# 3         S101          Jurong (North)  103.713400  1.350533
# 4         S102          Semakau Island  103.765717  1.190167

# %%
#Check shape in mss
stations.shape
# Out:
# (63, 4)

# %%
#Read file as mss
mss = pd.read_csv('mss_data.csv')

# %%
# Convert all columns to lowercase and replace spaces in column names.
mss.columns = mss.columns.str.lower().str.replace(' ', '_')

# %%
#Check data in mss
mss.head()
# Out:
#    unnamed:_0     station    year  month  day  daily_rainfall_total  \
# 0           0  Paya Lebar  2009.0    1.0  1.0                   0.0
# 1           1  Paya Lebar  2009.0    1.0  2.0                   0.5
# 2           2  Paya Lebar  2009.0    1.0  3.0                   0.0
# 3           3  Paya Lebar  2009.0    1.0  4.0                   1.6
# 4           4  Paya Lebar  2009.0    1.0  5.0                   2.5
#
#    highest_30_min_rainfall  highest_60_min_rainfall  highest_120_min_rainfall  \
# 0                      NaN                      NaN                       NaN
# 1                      NaN                      NaN                       NaN
# 2                      NaN                      NaN                       NaN
# 3                      NaN                      NaN                       NaN
# 4                      NaN                      NaN                       NaN
#
#    mean_temperature  maximum_temperature  minimum_temperature  \
# 0               NaN                 32.7                 24.0
# 1               NaN                 30.5                 24.0
# 2               NaN                 30.1                 25.0
# 3               NaN                 30.2                 24.6
# 4               NaN                 32.3                 25.2
#
#    mean_wind_speed  max_wind_speed
# 0              8.4             NaN
# 1             12.3             NaN
# 2             13.5             NaN
# 3             13.0             NaN
# 4             15.4             NaN

# %%
#drop unnamed column
mss.drop(['unnamed:_0'], axis=1, inplace=True)

# %%
# Check for missing values.
mss.isnull().sum()
# Out:
# station                          0
# year                           394
# month                          394
# day                            394
# daily_rainfall_total          8929
# highest_30_min_rainfall     118965
# highest_60_min_rainfall     119064
# highest_120_min_rainfall    119061
# mean_temperature            197072
# maximum_temperature         189395
# minimum_temperature         189437
# mean_wind_speed             189406
# max_wind_speed              190440
# dtype: int64

# %%
#Check data in mss
mss.head()
# Out:
#       Station    Year  Month  Day  Daily Rainfall Total  \
# 0  Paya Lebar  2009.0    1.0  1.0                   0.0
# 1  Paya Lebar  2009.0    1.0  2.0                   0.5
# 2  Paya Lebar  2009.0    1.0  3.0                   0.0
# 3  Paya Lebar  2009.0    1.0  4.0                   1.6
# 4  Paya Lebar  2009.0    1.0  5.0                   2.5
#
#    Highest 30 Min Rainfall  Highest 60 Min Rainfall  Highest 120 Min Rainfall  \
# 0                      NaN                      NaN                       NaN
# 1                      NaN                      NaN                       NaN
# 2                      NaN                      NaN                       NaN
# 3                      NaN                      NaN                       NaN
# 4                      NaN                      NaN                       NaN
#
#    Mean Temperature  Maximum Temperature  Minimum Temperature  \
# 0               NaN                 32.7                 24.0
# 1               NaN                 30.5                 24.0
# 2               NaN                 30.1                 25.0
# 3               NaN                 30.2                 24.6
# 4               NaN                 32.3                 25.2
#
#    Mean Wind Speed  Max Wind Speed
# 0              8.4             NaN
# 1             12.3             NaN
# 2             13.5             NaN
# 3             13.0             NaN
# 4             15.4             NaN

# %%
#Check shape in mss
mss.shape
# Out:
# (283907, 13)

# %%
#Check column header for station
for col in stations.columns:
    print(col)
# Out:
# station_code
# station_name
# longitude
# latitude

# %%
#Check column header for mss
for col in mss.columns:
    print(col)
# Out:
# Station
# Year
# Month
# Day
# Daily Rainfall Total
# Highest 30 Min Rainfall
# Highest 60 Min Rainfall
# Highest 120 Min Rainfall
# Mean Temperature
# Maximum Temperature
# Minimum Temperature
# Mean Wind Speed
# Max Wind Speed

# %%
#To check if station name (in stations) and Station (in mss) can be used to map
print(stations['station_name'].unique()), print(mss['Station'].unique()) 
print(stations['station_name'].unique().shape), print(mss['Station'].unique().shape)
# Out:
# ['Paya Lebar' 'Macritchie Reservoir' 'Lower Peirce Reservoir'
#  'Jurong (North)' 'Semakau Island' 'Admiralty' 'Admiralty West'
#  'Pulau Ubin' 'East Coast Parkway' 'Marina Barrage' 'Ang Mo Kio'
#  'Choa Chu Kang (West)' 'Serangoon North' 'Newton' 'Lim Chu Kang'
#  'Marine Parade' 'Choa Chu Kang (Central)' 'Tuas South' 'Pasir Panjang'
#  'Jurong Island' 'Dhoby Ghaut' 'Nicoll Highway' 'Botanic Garden'
#  'Choa Chu Kang (South)' 'Khatib' 'Whampoa' 'Tengah' 'Changi' 'Seletar'
#  'Pasir Ris (West)' 'Kampong Bahru' 'Jurong Pier' 'Ulu Pandan' 'Serangoon'
#  'Jurong (East)' 'Mandai' 'Tai Seng' 'Jurong (West)' 'Upper Thomson'
#  'Clementi' 'Buangkok' 'Sentosa Island' 'Chai Chee' 'Boon Lay (West)'
#  'Bukit Panjang' 'Kranji Reservoir' 'Upper Peirce Reservoir' 'Kent Ridge'
#  'Tanjong Pagar' 'Queenstown' 'Tanjong Katong' 'Somerset (Road)'
#  'Sembawang' 'Punggol' 'Tuas West' 'Simei' 'Boon Lay (East)' 'Toa Payoh'
#  'Tuas' 'Bukit Timah' 'Yishun' 'Buona Vista' 'Pasir Ris (Central)']
# ['Paya Lebar' 'Macritchie Reservoir' 'Lower Peirce Reservoir'
#  'Jurong (North)' 'Semakau Island' 'Admiralty' 'Admiralty West'
#  'Pulau Ubin' 'East Coast Parkway' 'Marina Barrage' 'Ang Mo Kio'
#  'Choa Chu Kang (West)' 'Serangoon North' 'Newton' 'Lim Chu Kang'
#  'Marine Parade' 'Choa Chu Kang (Central)' 'Tuas South' 'Pasir Panjang'
#  'Jurong Island' 'Dhoby Ghaut' 'Nicoll Highway' 'Botanic Garden'
#  'Choa Chu Kang (South)' 'Khatib' 'Whampoa' 'Tengah' 'Changi' 'Seletar'
#  'Pasir Ris (West)' 'Kampong Bahru' 'Jurong Pier' 'Ulu Pandan' 'Serangoon'
#  'Jurong (East)' 'Mandai' 'Tai Seng' 'Jurong (West)' 'Upper Thomson'
#  'Clementi' 'Buangkok' 'Sentosa Island' 'Chai Chee' 'Boon Lay (West)'
#  'Bukit Panjang' 'Kranji Reservoir' 'Upper Peirce Reservoir' 'Kent Ridge'
#  'Tanjong Pagar' 'Queenstown' 'Tanjong Katong' 'Somerset (Road)'
#  'Sembawang' 'Punggol' 'Tuas West' 'Simei' 'Boon Lay (East)' 'Toa Payoh'
#  'Tuas' 'Bukit Timah' 'Yishun' 'Buona Vista' 'Pasir Ris (Central)']
# (63,)
# (63,)
# (None, None)

# %%
Combined_1 = stations.merge(mss, left_on='station_name', right_on='Station')
Combined_1.head()
# Out:
#   station_code station_name   longitude  latitude     Station    Year  Month  \
# 0          S06   Paya Lebar  103.903733  1.357133  Paya Lebar  2009.0    1.0
# 1          S06   Paya Lebar  103.903733  1.357133  Paya Lebar  2009.0    1.0
# 2          S06   Paya Lebar  103.903733  1.357133  Paya Lebar  2009.0    1.0
# 3          S06   Paya Lebar  103.903733  1.357133  Paya Lebar  2009.0    1.0
# 4          S06   Paya Lebar  103.903733  1.357133  Paya Lebar  2009.0    1.0
#
#    Day  Daily Rainfall Total  Highest 30 Min Rainfall  \
# 0  1.0                   0.0                      NaN
# 1  2.0                   0.5                      NaN
# 2  3.0                   0.0                      NaN
# 3  4.0                   1.6                      NaN
# 4  5.0                   2.5                      NaN
#
#    Highest 60 Min Rainfall  Highest 120 Min Rainfall  Mean Temperature  \
# 0                      NaN                       NaN               NaN
# 1                      NaN                       NaN               NaN
# 2                      NaN                       NaN               NaN
# 3                      NaN                       NaN               NaN
# 4                      NaN                       NaN               NaN
#
#    Maximum Temperature  Minimum Temperature  Mean Wind Speed  Max Wind Speed
# 0                 32.7                 24.0              8.4             NaN
# 1                 30.5                 24.0             12.3             NaN
# 2                 30.1                 25.0             13.5             NaN
# 3                 30.2                 24.6             13.0             NaN
# 4                 32.3                 25.2             15.4             NaN

# %%
Combined_1.shape
# Out:
# (283907, 17)
